# %%
import pandas as pd
import prince
data =  pd.read_excel('G:/PythonPro/本地库/data/test.xlsx',sheet_name=0)
data = data.drop(['pax_name','emd_lable','pax_passport','seg_dep_time','flt_cnt_y2', 'flt_cnt_y3','birth_date','recent_flt_day'],axis=1)
data = data.fillna(0)

# %%
data.fillna(0)

y = data['emd_lable2']

X = data.drop(['emd_lable2'],axis=1)
famd = prince.FAMD(n_components=20)
X = famd.fit_transform(X)
X.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.441139  0.036597  0.059909  0.105511  0.244950  0.070364  0.041384
# 1  0.112473  0.966410 -0.112525 -0.215118 -0.132214  0.061292 -0.230312
# 2 -0.444932  0.034435  0.056068  0.107942  0.246056  0.068401  0.044063
# 3 -0.315284  0.029551  0.026721  0.052177  0.108668  0.024242  0.027100
# 4 -0.202896 -0.341587  0.046183  0.069318  0.107549  0.007892  0.008050
#
#          7         8         9         10        11        12        13  \
# 0  0.004624  0.032512  0.082031 -0.067023 -0.011274  0.063162 -0.025176
# 1  0.245879 -0.178096 -0.183816  0.335455  0.105958  0.367728 -0.195413
# 2  0.003404  0.035636  0.097109 -0.065188 -0.013399  0.068682 -0.025516
# 3 -0.002147  0.027451  0.013997 -0.022789 -0.028489 -0.021310 -0.002051
# 4  0.023450 -0.019446 -0.009931 -0.063405  0.047122  0.138411 -0.005511
#
#          14        15        16        17        18        19
# 0 -0.062163  0.044394  0.047273 -0.042202  0.061360 -0.030116
# 1 -0.324550 -1.010897  0.510674 -0.209679 -0.151320  0.314938
# 2 -0.064220  0.044753  0.049671 -0.043772  0.056726 -0.031651
# 3 -0.014177  0.030089 -0.003672 -0.009335 -0.002487 -0.021000
# 4 -0.063868 -0.000457 -0.081339  0.104894  0.134217  0.031721
